# %%
### 1. Mount Google Drive ###
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### 2. Define root directory ###
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# %%
### 3. Install Ultralytics ###
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.0/950.0 kB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
### 4. train model ###
import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt") #load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "dataset.yaml"), epochs=20) # train the model
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
print(locale.getdefaultlocale())
print(locale.getpreferredencoding())
# Out:
# ('en_US', 'UTF-8')
# ANSI_X3.4-1968

# %%
### 5. Copy results ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runstry'

# %%
### Train with 50 epochs YOLOv8 ###
import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt") #load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "dataset.yaml"), epochs=50) # train the model
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### Save 50 epcohs YOLOv8 ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs2')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs2'

# %%
### Train with 50 epochs YOLOv5 ###
import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolov5n.pt") #load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "dataset.yaml"), epochs=50) # train the model
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 304MB/s]
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### Save 50 epcohs YOLOv5 ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs3')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs3'

# %%
### Train with 50 epochs YOLOv11 ###
import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt") #load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "dataset.yaml"), epochs=50) # train the model
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### Save 50 epcohs YOLOv11 ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs4')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs4'

# %%
from ultralytics import YOLO

# Load the pretrained YOLOv11 model
model = YOLO("yolov8n.pt")

# Print model structure
print(model.model)
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
### YOLOv8 - 20 epochs - Freeze 5 layers ###
### Total backbone layers 10 - Freeze 50% ###

import os
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # Load pre-trained YOLOv8 nano model

# Use the model
results = model.train(
    data=os.path.join(ROOT_DIR, "dataset.yaml"),  # Path to dataset.yaml
    epochs=20,  # Number of epochs
    freeze=5  # Freeze the first 5 layers
)
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### Save 20 epcohs YOLOv8 - Freeze 5 layers ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs5')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs5'

# %%
from ultralytics import YOLO

# Load the pretrained YOLOv11 model
model = YOLO("yolov5n.pt")

# Print model structure
print(model.model)
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
### YOLOv5 - 20 epochs - Freeze 5 layers ###
### Total backbone layers 10 - Freeze 50% ###

import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolov5n.pt") #load pre trained model

# Use the model
results = model.train(
    data=os.path.join(ROOT_DIR, "dataset.yaml"),  # Path to dataset.yaml
    epochs=20,  # Number of epochs
    freeze=5  # Freeze the first 5 layers
)
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### Save 20 epcohs YOLOv5 - Freeze 5 layers ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs6')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs6'

# %%
from ultralytics import YOLO

# Load the pretrained YOLOv11 model
model = YOLO("yolo11n.pt")

# Print model structure
print(model.model)
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
### YOLOv11 - 20 epochs - Freeze 6 layers ###
### Total backbone layers 11 - Freeze 50% ###

import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt") #load pre trained model

# Use the model
results = model.train(
    data=os.path.join(ROOT_DIR, "dataset.yaml"),  # Path to dataset.yaml
    epochs=20,  # Number of epochs
    freeze=6  # Freeze the first 6 layers
)
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### Save 20 epcohs YOLOv11 - Freeze 6 layers ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs7')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs7'

# %%
### Testing with self_annotated dataset

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Load a pre-trained model
model = YOLO("yolov8n.pt")

# Path to the dataset.yaml file inside the self_annotated folder
data_path = os.path.join(ROOT_DIR, "self_annotated", "dataset.yaml")

# Train the model
results = model.train(data=data_path, epochs=10)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 79.2MB/s]
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### Save 10 epcohs YOLOv8 - Testing self_annotated ###
import shutil
shutil.copytree('/content/runs', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs8')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs8'

# %%
### First Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Load a pre-trained model
model = YOLO("yolov8n.pt")

# Path to the dataset.yaml file inside the self_annotated folder
data_path = os.path.join(ROOT_DIR, "full", "dataset.yaml")

# Train the model
results = model.train(data=data_path, epochs=25)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 116MB/s]
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 25 epcohs YOLOv8 - First Training ###
import shutil
shutil.copytree('/content/runs/detect/train', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train'

# %%
### Second Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "full", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=20, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 25 epochs YOLOv8 - Second Training ###
import shutil
shutil.copytree('/content/runs/detect/train2', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train2')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train2'

# %%
### Third Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train2/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "full", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=15, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 15 epochs YOLOv8 - Third Training ###
import shutil
shutil.copytree('/content/runs/detect/train3', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train3')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train3'

# %%
### Forth Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train3/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "full", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=10, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 10 epcohs YOLOv8 - Forth Training ###
import shutil
shutil.copytree('/content/runs/detect/train4', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train4')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train4'

# %%
### Fifth Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train4/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "partial", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=25, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 25 epochs YOLOv8 - Fifth Training ###
import shutil
shutil.copytree('/content/runs/detect/train5', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train5')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train5'

# %%
### Sixth Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train5/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "partial", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=20, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 20 epochs YOLOv8 - Sixth Training ###
import shutil
shutil.copytree('/content/runs/detect/train6', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train6')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train6'

# %%
### Seventh Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train6/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "partial", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=15, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 15 epochs YOLOv8 - Seventh Training ###
import shutil
shutil.copytree('/content/runs/detect/train7', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train7')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train7'

# %%
### Eighth Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train7/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "partial", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=10, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 10 epochs YOLOv8 - Eighth Training ###
import shutil
shutil.copytree('/content/runs/detect/train8', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train8')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train8'

# %%
### Ninth Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train8/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "self_annotated", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=25, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 25 epochs YOLOv8 - Ninth Training ###
import shutil
shutil.copytree('/content/runs/detect/train9', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train9')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train9'

# %%
### Tenth Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train9/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "self_annotated", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=20, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 20 epochs YOLOv8 - Tenth Training ###
import shutil
shutil.copytree('/content/runs/detect/train10', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train10')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train10'

# %%
### Eleventh Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train10/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "self_annotated", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=15, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 15 epochs YOLOv8 - Eleventh Training ###
import shutil
shutil.copytree('/content/runs/detect/train11', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train11')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train11'

# %%
### Twelveth Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train11/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "self_annotated", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=10, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 10 epochs YOLOv8 - Twelveth Training ###
import shutil
shutil.copytree('/content/runs/detect/train12', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train12')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train12'

# %%
### Thirteen Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train12/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "second_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=25, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 25 epochs YOLOv8 - Thirteen Training ###
import shutil
shutil.copytree('/content/runs/detect/train13', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train13')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train13'

# %%
### Forteen Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train13/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "second_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=20, resume=False)  # Change to True if resuming
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 20 epochs YOLOv8 - Forteen Training ###
import shutil
shutil.copytree('/content/runs/detect/train', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train14')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train14'

# %%
### Fifthteen Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train14/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "second_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=15, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 15 epochs YOLOv8 - Fifteen Training ###
import shutil
shutil.copytree('/content/runs/detect/train2', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train15')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train15'

# %%
### Sixteen Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train15/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "second_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=10, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 10 epochs YOLOv8 - Sixteen Training ###
import shutil
shutil.copytree('/content/runs/detect/train3', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train16')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train16'

# %%
### Seventeen Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train16/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "third_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=25, resume=False)  # Change to True if resuming
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 25 epochs YOLOv8 - Seventeen Training ###
import shutil
shutil.copytree('/content/runs/detect/train', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train17')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train17'

# %%
### Eighteen Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train17/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "third_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=20, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.97 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 20 epochs YOLOv8 - Eighteen Training ###
import shutil
shutil.copytree('/content/runs/detect/train2', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train18')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train18'

# %%
### Nineteen Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train18/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "third_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=15, resume=False)  # Change to True if resuming
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 15 epochs YOLOv8 - Nineteen Training ###
import shutil
shutil.copytree('/content/runs/detect/train', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train19')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train19'

# %%
### Twenty Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train19/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "third_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=10, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 10 epochs YOLOv8 - Twenty Training ###
import shutil
shutil.copytree('/content/runs/detect/train2', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train20')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train20'

# %%
### Twenty-One Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train20/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "bottle_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=25, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 25 epochs YOLOv8 - Twenty-One Training ###
import shutil
shutil.copytree('/content/runs/detect/train3', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train21')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train21'

# %%
# !pip uninstall torch torchvision torchaudio -y
# !rm -rf /usr/local/lib/python3.11/dist-packages/torch*
# !pip cache purge
# Out:
# Found existing installation: torch 2.6.0+cpu
# Uninstalling torch-2.6.0+cpu:
#   Successfully uninstalled torch-2.6.0+cpu
# Found existing installation: torchvision 0.21.0+cu118
# Uninstalling torchvision-0.21.0+cu118:
#   Successfully uninstalled torchvision-0.21.0+cu118
# Found existing installation: torchaudio 2.6.0+cu118
# Uninstalling torchaudio-2.6.0+cu118:
#   Successfully uninstalled torchaudio-2.6.0+cu118
# Files removed: 4

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.6.0+cu118

# %%
# !pip install --upgrade ultralytics torch torchvision torchaudio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 88.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.2
#     Uninstalling ultralytics-8.1.2:
#       Successfully uninstalled ultralytics-8.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 2.1.1 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.1 which is incompatible.
# ...

# %%
### Twenty-Two Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train21/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "bottle_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=20, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 20 epochs YOLOv8 - Twenty-Two Training ###
import shutil
shutil.copytree('/content/runs/detect/train4', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train22')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train22'

# %%
### Twenty-Three Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train22/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "bottle_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=15, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 15 epochs YOLOv8 - Twenty-Three Training ###
import shutil
shutil.copytree('/content/runs/detect/train5', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train23')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train23'

# %%
### Twenty-Four Training

import os
from ultralytics import YOLO

# Define root directory
ROOT_DIR = '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8'

# Path to the best checkpoint
best_model_path = os.path.join(ROOT_DIR, "runs/detect/train23/weights/best.pt")

# Load the model from the best.pt checkpoint
model = YOLO(best_model_path)  # Load model with previous weights

# Path to dataset.yaml file
data_path = os.path.join(ROOT_DIR, "bottle_dataset_roboflow", "dataset.yaml")

# Continue training for more epochs
results = model.train(data=data_path, epochs=10, resume=False)  # Change to True if resuming
# Out:
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
### Save 10 epochs YOLOv8 - Twenty-Four Training ###
import shutil
shutil.copytree('/content/runs/detect/train6', '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train24')
# Out:
# '/content/gdrive/My Drive/ComputerVision/TrashDetectionYOLOv8/runs/detect/train24'
